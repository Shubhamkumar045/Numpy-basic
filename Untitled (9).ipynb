# %%
import numpy as np
list_ = [ ‘1’ , ’2’ , ‘3’ , ‘4’ , ‘5’ ]
array_list = np.array(object = list_)
Q1. Is there any difference in the data type of variables list_ and array_list? If there is then write a code
to print the data types of both the variables.
Answer--import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_)

print("Data type of list_:", type(list_))
print("Data type of array_list:", type(array_list))

Q2. Write a code to print the data type of each and every element of both the variables list_ and
arra_list.
Answer--import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_)

print("Data type of each element in list_:")
for elem in list_:
    print(type(elem))

print("\nData type of each element in array_list:")
for elem in array_list:
    print(type(elem))
Q3. Considering the following changes in the variable, array_list:
array_list = np.array(object = list_, dtype = int)
Answer-Data Type Conversion: The elements of the list_ will be converted to integers during 
the creation of the NumPy array array_list. 
If any element in the original list cannot be converted to an integer, it will raise a ValueError.
import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_, dtype=int)

print(array_list)
print("Data type of array_list elements:", array_list.dtype)

Output:


[1 2 3 4 5]
Data type of array_list elements: int64

Consider the below code to answer further questions:
import numpy as np
num_list = [ [ 1 , 2 , 3 ] , [ 4 , 5 , 6 ] ]
num_array = np.array(object = num_list)
Q4. Write a code to find the following characteristics of variable, num_array:
(i) shape
(ii) size
Answer--import numpy as np

num_list = [[1, 2, 3], [4, 5, 6]]
num_array = np.array(object=num_list)

# (i) Shape of the array
shape = num_array.shape
print("Shape of num_array:", shape)

# (ii) Size of the array
size = num_array.size
print("Size of num_array:", size)

Q5. Write a code to create numpy array of 3*3 matrix containing zeros only, using a numpy array
creation function.
[Hint: The size of the array will be 9 and the shape will be (3,3).]
Answer--import numpy as np

# Creating a 3x3 array of zeros
zero_array = np.zeros((3, 3))

print("Array of zeros:")
print(zero_array)
